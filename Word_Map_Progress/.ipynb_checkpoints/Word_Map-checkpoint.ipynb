# %%
# credit goes to Wei Chun Chang for the amazing word map code at https://www.kaggle.com/justjun0321

# %%
#import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
# set filepath and establish DataFrame
df = pd.read_csv('../CSV_Folder/job_skills.csv')

# %%
# Is it working?
print(df.columns)
# Out:
# Index(['Company', 'Title', 'Category', 'Location', 'Responsibilities',
#        'Minimum Qualifications', 'Preferred Qualifications'],
#       dtype='object')

# %%
df = df.dropna(how='any',axis='rows')
df = df.reset_index(drop=True)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# 3           Developer Relations  Mountain View, CA, United States
# 4            Program Management      Sunnyvale, CA, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
# 3  Work one-on-one with the top Android, iOS, and...
# 4  Plan requirements with internal customers.\nPr...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
# 3  BA/BS degree in Computer Science or equivalent...
# 4  BA/BS degree or equivalent practical experienc...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...
# 3  Experience as a software developer, architect,...
# 4  CTS Certification.\nExperience in the construc...

# %%
BA_list = ['BA']
BS_list = ['BS']
Bachelor_list = ['BA/BS', 'Ba/Bs', 'ba/bs','Bachelor', 'bachelor']
Master_list = ['Master', 'master']
MBA_list = ['MBA', 'Mba', 'mba']
PhD_list = ['PHD', 'PhD', 'phD', 'phd', 'Phd']
PhD_re = "[pP][hH][dD]"

# %%
results = []
for row in list(df['Minimum Qualifications']):
    found = re.findall(PhD_re, row)
    results.append(len(found) > 0)
print(results[0:20])
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]

# %%
test = []

for row in range(len(df['Minimum Qualifications'])):    
    go=True
    if go==True:
        for word_phd in PhD_list:
            if word_phd in df['Minimum Qualifications'][row]:
                test.append("PhD")
                go=False
                break
    if go==True:
        for word_mba in MBA_list:
            if word_mba in df['Minimum Qualifications'][row]:
                test.append("MBA")
                go=False
                break

    if go==True:
        for word_master in Master_list:
            if word_master in df['Minimum Qualifications'][row]:
                test.append("Master's")
                go=False
                break
    if go==True:
        for word_bachelor in Bachelor_list:
            if word_bachelor in df['Minimum Qualifications'][row]:
                test.append("Bachelor's")
                go=False
                break
    if go==True:
        for word_ba in BA_list:
            if word_ba in df['Minimum Qualifications'][row]:
                test.append("BA")
                go=False
                break
    if go==True:

        for word_bs in BS_list:
            if word_bs in df['Minimum Qualifications'][row]:
                test.append("BS")
                go=False
                break
    if go==True:
        test.append('GED')
test
# Out:
# ["Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'GED',
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'BS',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'BS',
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'BS',
#  'GED',
#  'BS',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'GED',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  'BA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  'BS',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'PhD',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  'MBA',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Master's",
#  "Bachelor's",
#  'GED',
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BA',
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  "Master's",
#  'GED',
#  'GED',
#  'GED',
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  'MBA',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'BA',
#  "Bachelor's",
#  "Master's",
#  'BS',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  'BS',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'MBA',
#  'GED',
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'PhD',
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  'MBA',
#  'MBA',
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  'MBA',
#  "Bachelor's",
#  'PhD',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  'GED',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'MBA',
#  "Bachelor's",
#  'GED',
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'MBA',
#  'MBA',
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  'GED',
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'MBA',
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Master's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  "Bachelor's",
#  'GED',
#  "Bachelor's",
#  "Bachelor's",
#  ...]

# %%
len(test)
# Out:
# 1235

# %%
# This is the end of the good code, proceed at your own risk!
# 
# The NEXT MISSION: 
# apply this to the programming langauges
#

# %%
Degree_Requirements = []
for row in range(len(df['Minimum Qualifications'])):
    if any(word in df['Minimum Qualifications'][row] for word in PhD_list):
        Degree_Requirements.append('PhD')          
    elif any(word in sentence for word in MBA_list):
        Degree_Requirements.append('MBA') 
    elif any(word in sentence for word in Master_list):
        Degree_Requirements.append("Master's")
    elif any(word in sentence for word in Bachelor_list):
        Degree_Requirements.append("Bachelor's")
    elif any(word in sentence for word in BA_list):
        Degree_Requirements.append("BA")          
    elif any(word in sentence for word in BS_list):
        Degree_Requirements.append("BS")
    else:
        Degree_Requirements.append("GED")
              
print(Degree_Requirements[0:20])

# %%
# re.sub("[^\d]","","asdf(650)ljhaflkhj1234657--aks")
re.search("j(oin)? (.*)$", "join ,")[2]

this
that
wooooo
this,that,wooooooo

# %%
re.findall("q", "hello, world")

# %%
if word in df['Minimum Qualifications'][1] == 'phd':
    print (word)
else:
    print ('no word')

# %%
for word in PhD_list:
    print(word)

# %%
num_rows = 0
row_nums = []
for row in df["Company"]:
    row_nums.append(num_rows)
    num_rows +=1
row_nums[0:20]

# %%
BIG_WORD_LIST = []
row=0
while row < 20:
    for row in df['Responsibilities']:
        BIG_WORD_LIST.append(df.iloc[int(row_nums[row]),4])
        BIG_WORD_LIST.append(df.iloc[row,5])
        BIG_WORD_LIST.append(df.iloc[row,6])


len(BIG_WORD_LIST)

# %%
print(df.columns)
df['Category'].value_counts()

# %%
Programming_Languages = ['Python', 'Java ','C#', 'PHP', 'Javascript', 'Ruby', 'Perl', 'SQL','Go ']

Languages = dict((x,0) for x in Programming_Languages)
for i in Languages:
    x = df['Minimum Qualifications'].str.contains(i).sum()
    if i in Languages:
        Languages[i] = x
        
print(Languages)

# %%
type(Languages)
# PL_DF = pd.DataFrame.from_dict(Languages)
# PL_DF.head()

# %%
Degree = ['BA','BS','Bachelor','MBA','Master','PhD']

Degrees = dict((x,0) for x in Degree)
for i in Degree:
    x = df['Minimum Qualifications'].str.contains(i).sum()
    if i in Degrees:
        Degrees[i] = x
        
print(Degrees)

# %%
degree_requirement = sorted(Degrees.items(), key=lambda x: x[1], reverse=True)
degree = pd.DataFrame(degree_requirement,columns=['Degree','Count'])
degree['Count'] = degree.Count.astype('float')
degree

# %%
len(df['Minimum Qualifications'])

# %%
for x in range(2):
    print(df['Minimum Qualifications'][x])
type(x)

# %%
type(test)

# %%
Degree_Requirements = []
for row in range(len(df['Minimum Qualifications'])):
    if any(word in df['Minimum Qualifications'][row] for word in PhD_list):
        Degree_Requirements.append('PhD')          
    elif any(word in sentence for word in MBA_list):
        Degree_Requirements.append('MBA') 
    elif any(word in sentence for word in Master_list):
        Degree_Requirements.append("Master's")
    elif any(word in sentence for word in Bachelor_list):
        Degree_Requirements.append("Bachelor's")
    elif any(word in sentence for word in BA_list):
        Degree_Requirements.append("BA")          
    elif any(word in sentence for word in BS_list):
        Degree_Requirements.append("BS")
    else:
        Degree_Requirements.append("GED")
              
print(Degree_Requirements[0:20])

# %%
df['Category'].unique()

# %%
df_by_category = pd.DataFrame()

# %%
BIG_WORD_LIST[0].replace('\n',' ')

# %%
# find out which language occurs in most in minimum Qualifications string
from List_of_Programming_Languages.py import LoPL
wordcount = dict((x,0) for x in LoPL)
for w in re.findall(r"[\w'+#-]+|[.!?;’]", miniumum_qualifications_string):
    if w in wordcount:
        wordcount[w] += 1
# print
print(wordcount)

# %%
4th Dimension/4D
ABAP
ABC
ActionScript
Ada
Agilent VEE
Algol
Alice
Angelscript
Apex
APL
AppleScript
Arc

# %%
# Rename the columns to make them easier to code 
df = df.rename(columns={
    'Minimum Qualifications': 'Minimum_Qualifications', 
    'Preferred Qualifications': 'Preferred_Qualifications'})

# %%
# are there any NaN values in the DF?
pd.isnull(df).sum()

# %%
# Drop all those null rows
df = df.dropna(how='any',axis='rows')

# %%
# check to see if there are any other company names 
df.Company.value_counts()

# %%
# So I drop Youtube
# df = df[df.Company != 'YouTube']

# %%
df.Location.value_counts()[:15]

# %%
df['Country'] = df['Location'].apply(lambda x : x.split(',')[-1])

# %%
df.head(2)

# %%
df.Country.value_counts()[:15]

# %%
# The way to extract year refer to https://www.kaggle.com/niyamatalmass/what-you-need-to-get-a-job-at-google.
# Thanks Niyamat Ullah for such brilliant way. Go check his kernel. It's great!
import re
df['Minimum_years_experience'] = df['Minimum_Qualifications'].apply(lambda x : re.findall(r'([0-9]+) year',x))
# Fill empty list with [0]
df['Minimum_years_experience'] = df['Minimum_years_experience'].apply(lambda y : [0] if len(y)==0 else y)
# Then extract maximum in the list to have the work experience requirement
df['Minimum_years_experience'] = df['Minimum_years_experience'].apply(lambda z : max(z))
df['Minimum_years_experience'] = df.Minimum_years_experience.astype(int)
