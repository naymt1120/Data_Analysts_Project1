# %% [markdown]
# # Job Market for Data Analyst - From Different Perspectives
# Ali, Karen, Nay, Lynn, & Trip

# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Historical Data - Karen

# %%
# Make a reference to the books.csv file path# Make  
csv_path = "CSV_Folder/combined_data.csv"

# Import the books.csv file as a DataFrame
original_df = pd.read_csv(csv_path, encoding="utf-8")
original_df.head()
# Out:
#            Metro Dimension Type    Month         Dimension           Measure  \
# 0       National    Quick Facts  2018-06   U.S. Median Pay   U.S. Median Pay
# 1        Atlanta    Quick Facts  2018-06  Metro Median Pay  Metro Median Pay
# 2        Atlanta    Quick Facts  2018-06   U.S. Median Pay   U.S. Median Pay
# 3        Atlanta    Quick Facts  2018-06      Job Openings      Job Openings
# 4  New York City    Quick Facts  2018-06  Metro Median Pay  Metro Median Pay
#
#       Value    YoY
# 0   52052.0  0.016
# 1   53688.0  0.015
# 2   52052.0  0.016
# 3  133775.0  0.296
# 4   61741.0  0.022

# %%
glassdoor_df = original_df.rename(columns = {'Dimension Type': 'Dimension_type'})
glassdoor_df.head()
# Out:
#            Metro Dimension_type    Month         Dimension           Measure  \
# 0       National    Quick Facts  2018-06   U.S. Median Pay   U.S. Median Pay
# 1        Atlanta    Quick Facts  2018-06  Metro Median Pay  Metro Median Pay
# 2        Atlanta    Quick Facts  2018-06   U.S. Median Pay   U.S. Median Pay
# 3        Atlanta    Quick Facts  2018-06      Job Openings      Job Openings
# 4  New York City    Quick Facts  2018-06  Metro Median Pay  Metro Median Pay
#
#       Value    YoY
# 0   52052.0  0.016
# 1   53688.0  0.015
# 2   52052.0  0.016
# 3  133775.0  0.296
# 4   61741.0  0.022

# %%
glassdoor_df.shape
# Out:
# (27947, 7)

# %%
glassdoor_df.dtypes
# Out:
# Metro              object
# Dimension_type     object
# Month              object
# Dimension          object
# Measure            object
# Value             float64
# YoY               float64
# dtype: object

# %%
#Filter by Job Title = Data Analyst  & Data Scientist

filtered_df = glassdoor_df.query('Dimension_type == ["Job Title"]')
filtered_df = glassdoor_df[(glassdoor_df['Dimension']=='Data Analyst') | 
                           (glassdoor_df['Dimension']=='Data Scientist') |
                          (glassdoor_df['Dimension']=='Business Analyst')]
filtered_df.head()
# Out:
#         Metro Dimension_type    Month         Dimension          Measure  \
# 36   National      Job Title  2018-06  Business Analyst  Median Base Pay
# 59   National      Job Title  2018-06    Data Scientist  Median Base Pay
# 61   National      Job Title  2018-06      Data Analyst  Median Base Pay
# 120   Atlanta      Job Title  2018-06  Business Analyst  Median Base Pay
# 143   Atlanta      Job Title  2018-06    Data Scientist  Median Base Pay
#
#        Value    YoY
# 36   65004.0  0.007
# 59   94912.0 -0.002
# 61   60374.0  0.019
# 120  72012.0  0.007
# 143  98512.0 -0.003

# %% [markdown]
# # Median Salary Trend by Month

# %%
period_df = filtered_df[['Month','Dimension','Value']]
period_df.head()
# Out:
#        Month         Dimension    Value
# 36   2018-06  Business Analyst  65004.0
# 59   2018-06    Data Scientist  94912.0
# 61   2018-06      Data Analyst  60374.0
# 120  2018-06  Business Analyst  72012.0
# 143  2018-06    Data Scientist  98512.0

# %%
#Extra - Average Median Salary by Month
month_average = period_df.groupby(["Month"]).mean()['Value']
month_average
# Out:
# Month
# 2017-06    83545.055556
# 2017-07    84302.000000
# 2017-08    84742.121212
# 2017-09    84328.212121
# 2017-10    83873.181818
# 2017-11    83088.909091
# 2017-12    84191.363636
# 2018-01    83674.909091
# 2018-02    84815.787879
# 2018-03    85131.181818
# 2018-04    85125.303030
# 2018-05    84700.727273
# 2018-06    84605.060606
# 2018-07    85181.393939
# Name: Value, dtype: float64

# %%
salary_by_title= pd.DataFrame(period_df.groupby(["Month","Dimension"]).mean()['Value'])
salary_by_title.head()
# Out:
#                                   Value
# Month   Dimension
# 2017-06 Business Analyst   73969.833333
#         Data Analyst       68989.666667
#         Data Scientist    107675.666667
# 2017-07 Business Analyst   74477.545455
#         Data Analyst       69598.636364

# %%
title_df = salary_by_title.reset_index().set_index('Month')

# %%
title_df[['Data Analyst']] = title_df.groupby('Dimension').get_group('Data Analyst')[['Value']]
title_df[['Data Scientist']] = title_df.groupby('Dimension').get_group('Data Scientist')[['Value']]
title_df[['Business Analyst']] = title_df.groupby('Dimension').get_group('Business Analyst')[['Value']]

# %%
grouped_by_title = title_df[['Data Analyst', 'Data Scientist', 'Business Analyst']]

# %%
position_graph = grouped_by_title[~grouped_by_title.index.duplicated(keep='first')]

# %%
position_graph.plot(kind = 'bar',alpha=0.5, align='center', width = .7, figsize = (10,5))

plt.title("Median Salary Trend")
plt.xlabel("Period")
plt.ylabel("Median Base Pay ($)")

lgnd = plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, 
                  loc=(1.1,.7), title="Job Titles", 
                  labelspacing=0.5)

margin = 0.05

plt.savefig('trend_by_period.png')

# %% [markdown]
# # Median Salary Trend by Region

# %%
region_df = filtered_df[['Metro','Dimension','Value']]
region_df.head()
# Out:
#         Metro         Dimension    Value
# 36   National  Business Analyst  65004.0
# 59   National    Data Scientist  94912.0
# 61   National      Data Analyst  60374.0
# 120   Atlanta  Business Analyst  72012.0
# 143   Atlanta    Data Scientist  98512.0

# %%
salary_by_region= pd.DataFrame(region_df.groupby(["Metro","Dimension"]).mean()['Value'])
salary_by_region.head()

#region_average
# Out:
#                                  Value
# Metro   Dimension
# Atlanta Business Analyst  71666.600000
#         Data Analyst      65070.333333
#         Data Scientist    96154.000000
# Boston  Business Analyst  75578.071429
#         Data Analyst      69902.571429

# %%
title_region_df = salary_by_region.reset_index().set_index('Metro')
#title_region_df

# %%
title_region_df[['Data Analyst']] = title_region_df.groupby('Dimension').get_group('Data Analyst')[['Value']]
title_region_df[['Data Scientist']] = title_region_df.groupby('Dimension').get_group('Data Scientist')[['Value']]

# %%
grouped_by_title2 = title_region_df[['Data Analyst', 'Data Scientist']]

# %%
region_graph = grouped_by_title2[~grouped_by_title2.index.duplicated(keep='first')]
region_graph
# Out:
#                Data Analyst  Data Scientist
# Metro
# Atlanta        65070.333333    96154.000000
# Boston         69902.571429   109327.428571
# Chicago        65282.857143   100557.571429
# Houston        64070.285714   105633.571429
# Los Angeles    71498.928571   115952.785714
# National       59125.642857    95620.285714
# New York City  71451.785714   113369.785714
# Philadelphia   63029.071429    98255.642857
# San Francisco  88754.357143   136822.000000
# Seattle        71537.857143   124330.642857
# Washington DC  71670.428571   104350.071429

# %%
region_graph[['Data Analyst']].plot(kind='bar', y = 'Data Analyst', yticks = None,legend = False, 
                                    fontsize=10, figsize = (10,5))

plt.title("Average Data Analyst Salary by Region ($)")
plt.xlabel("Metro Cities")
plt.ylabel("Median Base Salary ($)")
#plt.grid(True)

plt.savefig('Data_Analyst_Cities.png')

# %%
region_graph[['Data Scientist']].plot(kind='bar', y = 'Data Scientist', yticks = None,legend = False, 
                                      fontsize=10, figsize = (10,5))

plt.title("Average Data Scientist Salary by Region ($)")
plt.xlabel("Metro Cities")
plt.ylabel("Median Base Salary ($)")

plt.savefig('Data_Scientiest_Cities.png')

# %% [markdown]
# # Global / People Already in Data Science - Nay

# %%
data_file = "CSV_Folder/Survey.csv"
survey_df = pd.read_csv(data_file, encoding='ISO-8859-1')
survey_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# 1                 NaN        NaN            NaN
# 2                 NaN        NaN            NaN
# 3                 NaN        Yes            NaN
# 4                 NaN        Yes            NaN
#
#               CurrentJobTitleSelect TitleFit              ...                \
# 0             DBA/Database Engineer     Fine              ...
# 1                               NaN      NaN              ...
# 2                               NaN      NaN              ...
# 3  Operations Research Practitioner   Poorly              ...
# 4                Computer Scientist     Fine              ...
#
#   JobFactorExperienceLevel JobFactorDepartment  JobFactorTitle  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2           Very Important      Very Important  Very Important
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
#
#   JobFactorCompanyFunding JobFactorImpact JobFactorRemote JobFactorIndustry  \
# 0                     NaN             NaN             NaN               NaN
# 1                     NaN             NaN             NaN               NaN
# 2          Very Important  Very Important  Very Important    Very Important
# 3                     NaN             NaN             NaN               NaN
# 4                     NaN             NaN             NaN               NaN
#
#   JobFactorLeaderReputation JobFactorDiversity JobFactorPublishingOpportunity
# 0                       NaN                NaN                            NaN
# 1        Somewhat important                NaN                            NaN
# 2            Very Important     Very Important                 Very Important
# 3                       NaN                NaN                            NaN
# 4                       NaN                NaN                            NaN
#
# [5 rows x 228 columns]

# %%
# Create New Datafram - Pick out Columns of Interest
newsurvey_df = survey_df[['Age','Country','GenderSelect', 'LanguageRecommendationSelect', 'FormalEducation', 'MajorSelect']]
newsurvey_df.head()
# Out:
#     Age        Country                                       GenderSelect  \
# 0   NaN            NaN  Non-binary, genderqueer, or gender non-conforming
# 1  30.0  United States                                             Female
# 2  28.0         Canada                                               Male
# 3  56.0  United States                                               Male
# 4  38.0         Taiwan                                               Male
#
#   LanguageRecommendationSelect    FormalEducation  \
# 0                           F#  Bachelor's degree
# 1                       Python    Master's degree
# 2                            R    Master's degree
# 3                       Python    Master's degree
# 4                       Python    Doctoral degree
#
#                           MajorSelect
# 0      Management information systems
# 1                    Computer Science
# 2  Engineering (non-computer focused)
# 3           Mathematics or statistics
# 4  Engineering (non-computer focused)

# %%
newsurvey_df.dtypes
# Out:
# Age                             float64
# Country                          object
# GenderSelect                     object
# LanguageRecommendationSelect     object
# FormalEducation                  object
# MajorSelect                      object
# dtype: object

# %%
# Average Age
average_age = newsurvey_df['Age'].mean()
average_age
# Out:
# 32.372802734375

# %% [markdown]
# # Looking at Global Market

# %%
country_group = newsurvey_df.groupby('Country')
count_country = country_group['Country'].count()

count_country.head()
# Out:
# Country
# Argentina     92
# Australia    421
# Belarus       54
# Belgium       91
# Brazil       465
# Name: Country, dtype: int64

# %%
countries_bar = count_country.plot (kind='bar', y = 'n', yticks = None,legend = False, 
                                      fontsize=15, figsize = (20,6), color = 'skyblue')
plt.title("Where Do You Work?")
plt.xlabel("Country")
plt.ylabel("Numbers of People")
# Out:
# Text(0,0.5,'Numbers of People')

# %% [markdown]
# # Recommended Programming Languages

# %%
lang_group = survey_df.groupby('LanguageRecommendationSelect')
count_lang = lang_group['LanguageRecommendationSelect'].count()

count_lang
# Out:
# LanguageRecommendationSelect
# C/C++/C#     307
# F#             4
# Haskell       17
# Java         138
# Julia         30
# Matlab       238
# Other         85
# Python      6941
# R           2643
# SAS           88
# SQL          385
# Scala         94
# Stata         28
# Name: LanguageRecommendationSelect, dtype: int64

# %%
Languages = ['Python', 'R', 'SQL', 'C/C++/C#', 'Matlab', 'Java', 'Scala', 'SAS', 'Other', 'Julia', 'Stata', 'Haskell', 'F#']
Rec_count = [307, 4, 17, 138, 30, 238, 85, 6941, 2643, 88, 385, 94, 28]

Rec_count2 = sorted(Rec_count, key=int, reverse=True)

lang_df = pd.DataFrame({'Languages': Languages,'Count': Rec_count2})
lang_df
# Out:
#    Languages  Count
# 0     Python   6941
# 1          R   2643
# 2        SQL    385
# 3   C/C++/C#    307
# 4     Matlab    238
# 5       Java    138
# 6      Scala     94
# 7        SAS     88
# 8      Other     85
# 9      Julia     30
# 10     Stata     28
# 11   Haskell     17
# 12        F#      4

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(15,8))
ax = sns.barplot(x="Languages", y="Count", data=lang_df, color = 'skyblue')
ax.set_title('What Programming Language Do You Recommend?')
ax.set_ylabel('Votes')
# Out:
# Text(0,0.5,'Votes')

# %% [markdown]
# # Formal Education

# %%
edu_group = newsurvey_df.groupby('FormalEducation')
count_edu = edu_group['FormalEducation'].count()

count_edu
# Out:
# FormalEducation
# Bachelor's degree                                                    4811
# Doctoral degree                                                      2346
# I did not complete any formal education past high school              257
# I prefer not to answer                                                 90
# Master's degree                                                      6273
# Professional degree                                                   451
# Some college/university study without earning a bachelor's degree     786
# Name: FormalEducation, dtype: int64

# %%
Edu = ['Bachelors', 'Doctoral', 'GED', 'No Answer', 'Masters', 'Professional', 'Some College']
Edu_count = [4811, 2346, 257, 90, 6273, 451, 786]

Edu_df = pd.DataFrame({'Formal Education': Edu ,'Count': Edu_count})
Edu_df
# Out:
#   Formal Education  Count
# 0        Bachelors   4811
# 1         Doctoral   2346
# 2              GED    257
# 3        No Answer     90
# 4          Masters   6273
# 5     Professional    451
# 6     Some College    786

# %%
activities = ['Bachelors', 'Doctoral', 'GED', 'No Answer', 'Masters', 'Professional', 'Some College']
slices_hours = [4811, 2346, 257, 90, 6273, 451, 786]
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

fig = plt.figure(figsize=[10, 10])
plt.pie(slices_hours, labels=activities, colors=colors, startangle=90, autopct='%.1f%%', textprops={'fontsize': 14})
plt.title('Percentages of Formal Education')
plt.rcParams['font.size'] = 9.0
plt.show()

# %% [markdown]
# # US Job Market - Lynn

# %%
dice_data="CSV_Folder/dice_com_us_job_sample.csv"

# Read file into pandas data frame
dice_df = pd.read_csv(dice_data)
dice_df.head()
# Out:
#                                       advertiser_url  \
# 0  https://www.dice.com/jobs/detail/Business-Syst...
# 1  https://www.dice.com/jobs/detail/Business-Anal...
# 2  https://www.dice.com/jobs/detail/Business-Syst...
# 3  https://www.dice.com/jobs/detail/Business-Anal...
# 4  https://www.dice.com/jobs/detail/Business-Anal...
#
#                            company employmenttype_jobstatus  \
# 0  VanderHouwen & Associates, Inc.    Contract W2, Contract
# 1  VanderHouwen & Associates, Inc.     Full Time, Full time
# 2  VanderHouwen & Associates, Inc.    Contract W2, Contract
# 3                             SMCI           Contract W2, 5
# 4                             SMCI                C2H W2, 6
#
#                                      job_description               jobid  \
# 0  VanderHouwen has more jobs you may like! Find ...   Dice Id : vhassoc
# 1  PLEASE JOIN OUR TALENT NETWORK: http://bit.ly/...   Dice Id : vhassoc
# 2  PLEASE JOIN OUR TALENT NETWORK: http://bit.ly/...   Dice Id : vhassoc
# 3  Job Description: Seeking a Business Process An...  Dice Id : 10301550
# 4  Job Description: Our banking client is looking...      Dice Id : smci
#
#   job_location         job_title     postdate  \
# 0           OR   Systems Analyst  7 hours ago
# 1           WA  Business Analyst  7 hours ago
# 2           OR   Systems Analyst  7 hours ago
# 3           CA  Business Analyst  5 hours ago
# 4           CA  Business Analyst  5 hours ago
#
#                                               skills  \
# 0                            AI, Maya, Browzwear, 3D
# 1                                                SQL
# 2                     B2C digital product management
# 3  Mortgage/Equiting Lending, Lean Six Sigma Gree...
# 4  digital analytics, Google, Adobe, Tableau, For...
#
#                             uniq_id     ...       Unnamed: 36  Unnamed: 37  \
# 0  b923d29624fb4dc9e193aa30f8253ee6     ...               NaN          NaN
# 1  510481dba5a43cc2b77546f0dadb1ce4     ...               NaN          NaN
# 2  8d0ffe9061aa61fbd3fdfae28fa9e2b9     ...               NaN          NaN
# 3  0445fcb37ab17f686c025da15a98de52     ...               NaN          NaN
# 4  bb39139fe34f98132e057d2bc5f27ffc     ...               NaN          NaN
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 46 columns]

# %%
# Display total number of job listings in the U.S.# Displ 
combined_total_jobs = dice_df["uniq_id"].nunique()
combined_total_jobs
# Out:
# 988

# %%
# Display number of listings per state
state_count = dice_df["job_location"].value_counts()
state_count

# Create a data frame that holds state cunt summary
state_count_df=pd.DataFrame(state_count)
state_count_df.head()

#Change column name from 'job_location' to 'Total Job Listings'
state_count_df = state_count_df.rename(columns={"job_location":"Total Job Listings"})
state_count_df.head()
# Out:
#     Total Job Listings
# CA                 145
# NY                 127
# MA                  98
# TX                  80
# GA                  77

# %%
states = ["CA", "NY", "MA", "TX", "GA", "WA", "NJ", "CT", "PA", "VA", "IL", "MD", "FL", "MN", 
          "MI", "OH", "WI", "RI", "NC", "CO", "MO", "NE", "DC", "AZ", "NH", "DE", "SC", "LA", 
          "OR", "KS", "IA", "ME", "NV", "TN", "KY", "HI", "UT", "IN", "MD"]
state_totals = [145, 127,  98,  80,  77,  76,  72,  48,  46,  32,  27,  19,  18,
        14,  11,   9,   8,   7,   7,   7,   6,   6,   6,   5,   5,   5,
         4,   3,   3,   3,   2,   2,   2,   2,   2,   1,   1,   1,   1]
x_axis = np.arange(len(state_totals))
                
# Create a bar chart
plt.bar(x_axis, state_totals, color = 'b', alpha=0.5, align="center")

# Create the ticks for bar chart's x-axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, states)

# Add title and labels to bar chart
plt.title ("Number of Tech Job Listings in the US")
plt.xlabel("State")
plt.ylabel("Number of Job Listings")

# Set x limits of bar chart
plt.xlim(-0.95, len(x_axis)-30)

# Set y limits of bar chart# Set y 
plt.ylim(0, max(state_totals)+10)

plt.figure(figsize=(15,8))

# %%
# Separate data into fields according to 'job_title' values# Separ 
grouped_jobs_df = dice_df.groupby(['job_title'])
print(grouped_jobs_df)
grouped_jobs_df.count()
# Out:
# <pandas.core.groupby.groupby.DataFrameGroupBy object at 0x1a1bfef9e8>
#                                  advertiser_url  company  \
# job_title
# Big Data Analyst                              2        2
# Big Data Architect                           23       23
# Big Data Developer                           17       17
# Big Data Engineer                            28       28
# Business Analyst                            235      234
# Business Intelligence Analyst                43       43
# Business Intelligence Analyst                 2        2
# Business Intelligence Architect               2        2
# Business Intelligence Developer              43       43
# Data Analyst                                 82       82
# Data Architect                               39       39
# Data Engineer                                25       25
# Data Scientist                               40       40
# Data Warehouse Developer                     17       17
# Database Administrator                       29       29
# Database Developer                           17       17
# Database Engineer                            14       14
# SQL Database Administrator                   46       46
# SQL Developer                                33       33
# Software Engineer                             9        9
# Systems Administrator                        54       54
# Systems Analyst                              78       78
# Systems Developer                            14       14
# Systems Engineer                             76       75
# Tableau Developer                            20       20
#
#                                  employmenttype_jobstatus  job_description  \
# job_title
# Big Data Analyst                                        2                2
# Big Data Architect                                     23               23
# Big Data Developer                                     17               17
# Big Data Engineer                                      28               28
# Business Analyst                                      234              235
# Business Intelligence Analyst                          43               43
# Business Intelligence Analyst                           2                2
# Business Intelligence Architect                         2                2
# Business Intelligence Developer                        43               43
# Data Analyst                                           82               82
# Data Architect                                         39               39
# Data Engineer                                          25               25
# Data Scientist                                         40               40
# Data Warehouse Developer                               17               17
# Database Administrator                                 28               29
# Database Developer                                     17               17
# Database Engineer                                      14               14
# SQL Database Administrator                             46               46
# SQL Developer                                          33               33
# Software Engineer                                       9                9
# Systems Administrator                                  54               54
# Systems Analyst                                        78               78
# Systems Developer                                      14               14
# Systems Engineer                                       76               76
# Tableau Developer                                      20               20
#
#                                  jobid  job_location  postdate  skills  \
# job_title
# Big Data Analyst                     2             2         2       2
# Big Data Architect                  23            23        23      23
# Big Data Developer                  17            17        17      17
# Big Data Engineer                   28            28        28      28
# Business Analyst                   235           235       235     232
# Business Intelligence Analyst       43            43        43      43
# Business Intelligence Analyst        2             2         2       2
# Business Intelligence Architect      2             2         2       2
# Business Intelligence Developer     43            43        43      43
# Data Analyst                        82            82        82      82
# Data Architect                      39            39        39      39
# Data Engineer                       25            25        25      25
# Data Scientist                      40            40        40      40
# Data Warehouse Developer            17            17        17      17
# Database Administrator              29            29        29      29
# Database Developer                  17            17        17      17
# Database Engineer                   14            14        14      14
# SQL Database Administrator          46            46        46      46
# SQL Developer                       33            33        33      33
# Software Engineer                    9             9         9       9
# Systems Administrator               54            54        54      54
# Systems Analyst                     78            78        78      77
# Systems Developer                   14            14        14      14
# Systems Engineer                    76            76        76      74
# Tableau Developer                   20            20        20      20
#
#                                  uniq_id  Unnamed: 10     ...       \
# job_title                                                 ...
# Big Data Analyst                       2            0     ...
# Big Data Architect                    23            0     ...
# Big Data Developer                    17            0     ...
# Big Data Engineer                     28            0     ...
# Business Analyst                     235            0     ...
# Business Intelligence Analyst         43            0     ...
# Business Intelligence Analyst          2            0     ...
# Business Intelligence Architect        2            0     ...
# Business Intelligence Developer       43            0     ...
# Data Analyst                          82            0     ...
# Data Architect                        39            0     ...
# Data Engineer                         25            0     ...
# Data Scientist                        40            0     ...
# Data Warehouse Developer              17            0     ...
# Database Administrator                29            0     ...
# Database Developer                    17            0     ...
# Database Engineer                     14            0     ...
# SQL Database Administrator            46            0     ...
# SQL Developer                         33            0     ...
# Software Engineer                      9            0     ...
# Systems Administrator                 54            0     ...
# Systems Analyst                       78            0     ...
# Systems Developer                     14            0     ...
# Systems Engineer                      76            0     ...
# Tableau Developer                     20            0     ...
#
#                                  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# job_title
# Big Data Analyst                           0            0            0
# Big Data Architect                         0            0            0
# Big Data Developer                         0            0            0
# Big Data Engineer                          0            0            0
# Business Analyst                           2            2            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Architect            0            0            0
# Business Intelligence Developer            1            0            0
# Data Analyst                               0            0            0
# Data Architect                             0            0            0
# Data Engineer                              0            0            0
# Data Scientist                             1            1            1
# Data Warehouse Developer                   0            0            0
# Database Administrator                     0            0            0
# Database Developer                         0            0            0
# Database Engineer                          0            0            0
# SQL Database Administrator                 0            0            0
# SQL Developer                              0            0            0
# Software Engineer                          0            0            0
# Systems Administrator                      0            0            0
# Systems Analyst                            0            0            0
# Systems Developer                          1            0            0
# Systems Engineer                           3            3            3
# Tableau Developer                          0            0            0
#
#                                  Unnamed: 39  Unnamed: 40  Unnamed: 41  \
# job_title
# Big Data Analyst                           0            0            0
# Big Data Architect                         0            0            0
# Big Data Developer                         0            0            0
# Big Data Engineer                          0            0            0
# Business Analyst                           0            0            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Architect            0            0            0
# Business Intelligence Developer            0            0            0
# Data Analyst                               0            0            0
# Data Architect                             0            0            0
# Data Engineer                              0            0            0
# Data Scientist                             0            0            0
# Data Warehouse Developer                   0            0            0
# Database Administrator                     0            0            0
# Database Developer                         0            0            0
# Database Engineer                          0            0            0
# SQL Database Administrator                 0            0            0
# SQL Developer                              0            0            0
# Software Engineer                          0            0            0
# Systems Administrator                      0            0            0
# Systems Analyst                            0            0            0
# Systems Developer                          0            0            0
# Systems Engineer                           3            2            2
# Tableau Developer                          0            0            0
#
#                                  Unnamed: 42  Unnamed: 43  Unnamed: 44  \
# job_title
# Big Data Analyst                           0            0            0
# Big Data Architect                         0            0            0
# Big Data Developer                         0            0            0
# Big Data Engineer                          0            0            0
# Business Analyst                           0            0            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Analyst              0            0            0
# Business Intelligence Architect            0            0            0
# Business Intelligence Developer            0            0            0
# Data Analyst                               0            0            0
# Data Architect                             0            0            0
# Data Engineer                              0            0            0
# Data Scientist                             0            0            0
# Data Warehouse Developer                   0            0            0
# Database Administrator                     0            0            0
# Database Developer                         0            0            0
# Database Engineer                          0            0            0
# SQL Database Administrator                 0            0            0
# SQL Developer                              0            0            0
# Software Engineer                          0            0            0
# Systems Administrator                      0            0            0
# Systems Analyst                            0            0            0
# Systems Developer                          0            0            0
# Systems Engineer                           2            2            2
# Tableau Developer                          0            0            0
#
#                                  Unnamed: 45
# job_title
# Big Data Analyst                           0
# Big Data Architect                         0
# Big Data Developer                         0
# Big Data Engineer                          0
# Business Analyst                           0
# Business Intelligence Analyst              0
# Business Intelligence Analyst              0
# Business Intelligence Architect            0
# Business Intelligence Developer            0
# Data Analyst                               0
# Data Architect                             0
# Data Engineer                              0
# Data Scientist                             0
# Data Warehouse Developer                   0
# Database Administrator                     0
# Database Developer                         0
# Database Engineer                          0
# SQL Database Administrator                 0
# SQL Developer                              0
# Software Engineer                          0
# Systems Administrator                      0
# Systems Analyst                            0
# Systems Developer                          0
# Systems Engineer                           1
# Tableau Developer                          0
#
# [25 rows x 45 columns]

# %% [markdown]
# # Looking at a Specific Company - Trip

# %%
# My initial hypothesis was: 
# If Data Analysis is a discrete career field, 
# then there should come combination of education, 
# programming languages, and skills that set it 
# apart from other career fields.

# %%
# The way I was going to do this was to this was to

# %%
# set filepath and establish DataFrame
googdf = pd.read_csv('CSV_Folder/job_skills.csv')
monsterdf = pd.read_csv('CSV_Folder/Monster_Com_Job_Sample.csv')

# %%
# Is it working?
print(f"Number of Google job results: {len(googdf)}")
print(f"Number of Monster Analyst job results: {len(monsterdf['Organization'])}\n")

print(googdf.columns)
print(f"{monsterdf.columns}\n")

# print(googdf['Category'].value_counts())
# print(monsterdf['Organization'].value_counts())
# Out:
# Number of Google job results: 1235
# Number of Monster Analyst job results: 74
#
# Index(['Company', 'Title', 'Category', 'Location', 'Responsibilities',
#        'Minimum Qualifications', 'Preferred Qualifications',
#        'Degree Requirement'],
#       dtype='object')
# Index(['country', 'country_code', 'date_added', 'has_expired', 'job_board',
#        'Job_Description', 'Requirement', 'Job_Title', 'Job_Type', 'Location',
#        'Organization', 'Page_URL', 'Salary', 'Sector', 'Uniq_ID',
#        'Degree Requirement'],
#       dtype='object')

# %%
# Drop the incomplete rows and reset the index.
googdf = googdf.dropna(how='any',axis='rows')
googdf = googdf.reset_index(drop=True)

# Check their length again
print(f"Number of Google job results: {len(googdf)}")
print(f"Number of Monster Analyst job results: {len(monsterdf['Organization'])}\n")
# Out:
# Number of Google job results: 1235
# Number of Monster Analyst job results: 74

# %%
googdf.head(1)
# Out:
#   Company                         Title            Category   Location  \
# 0  Google  Google Cloud Program Manager  Program Management  Singapore
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...

# %%
monsterdf.head(1)
# Out:
#                     country country_code  date_added has_expired  \
# 0  United States of America           US         NaN          No
#
#           job_board                                    Job_Description  \
# 0  jobs.monster.com  Business & Strategy AnalystOne of our top clie...
#
#    Requirement                    Job_Title             Job_Type     Location  \
# 0          NaN  Business & Strategy Analyst  Full Time, Employee  Houston, TX
#
#      Organization                                           Page_URL Salary  \
# 0  Legal Services  http://jobview.monster.com/Business-amp-Strate...    NaN
#
#                           Sector                           Uniq_ID
# 0  Business/Strategic Management  9331cb7b561348a692f7afc58ac78926

# %%
# This is what two of the job description cells look like:
print(f"{googdf['Minimum Qualifications'][0]}\n\n\n {googdf['Minimum Qualifications'][1]}")
# Out:
# BA/BS degree or equivalent practical experience.
# 3 years of experience in program and/or project management in cloud computing, enterprise software and/or marketing technologies.
#
#
#  BS degree in an Engineering discipline or equivalent practical experience.
# 7 years of experience in Cable/Connector Design or Manufacturing in an NPI role.
# Experience working with Interconnect Engineering and Product Design (PD)/Mechanical Engineer in developing, manufacturing and testing.
# Ability to speak and write in English and Mandarin fluently and idiomatically.

# %%
BA_list = ['BA']
BS_list = ['BS']
Bachelor_list = ['BA/BS', 'BS/BA', 'bs/ba', 'Ba/Bs', 'ba/bs','Bachelor', 'bachelor']
Master_list = ['Master', 'master']
MBA_list = ['MBA', 'Mba', 'mba']
PhD_list = ['PHD', 'PhD', 'phD', 'phd', 'Phd', 'Ph.D']
PhD_re = "[pP][hH][dD]"
degree_list = [PhD_list, MBA_list, Master_list, Bachelor_list, BS_list, BA_list]
degrees = ["PhD", "MBA", "Master's", "Bachelor's", "BA", "BS", "GED"]

# %%
# make an array that will hold the degree requirements
DegreeColumn1 = []

for row in range(len(googdf['Minimum Qualifications'])):    
    go=True
    if go==True:
        for word_phd in PhD_list:
            if word_phd in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("PhD")
                go=False
                break
    if go==True:
        for word_mba in MBA_list:
            if word_mba in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("MBA")
                go=False
                break

    if go==True:
        for word_master in Master_list:
            if word_master in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("Master's")
                go=False
                break
    if go==True:
        for word_bachelor in Bachelor_list:
            if word_bachelor in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("Bachelor's")
                go=False
                break
    if go==True:
        for word_ba in BA_list:
            if word_ba in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("BA")
                go=False
                break
    if go==True:

        for word_bs in BS_list:
            if word_bs in googdf['Minimum Qualifications'][row]:
                DegreeColumn1.append("BS")
                go=False
                break
    if go==True:
        DegreeColumn1.append('No Mention')

# %%
DegreeColumn2 = []

for row in range(len(monsterdf['Job_Description'])):    
    go=True
    if go==True:
        for word_phd in PhD_list:
            if word_phd in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("PhD")       
                go=False
                break
    if go==True:
        for word_mba in MBA_list:
            if word_mba in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("MBA")
                go=False
                break

    if go==True:
        for word_master in Master_list:
            if word_master in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("Master's")
                go=False
                break
    if go==True:
        for word_bachelor in Bachelor_list:
            if word_bachelor in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("Bachelor's")
                go=False
                break
    if go==True:
        for word_ba in BA_list:
            if word_ba in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("BA")
                go=False
                break
    if go==True:

        for word_bs in BS_list:
            if word_bs in monsterdf['Job_Description'][row]:
                DegreeColumn2.append("BS")
                go=False
                break
    if go==True:
        DegreeColumn2.append('No Mention')

# %%
# test the length of the array to see if it is the same length of the DataFrame.
# if it is the same length, then it is probably safe to make a new column.
print(len(DegreeColumn1))
print(len(googdf['Minimum Qualifications']))
print(len(DegreeColumn2))
print(len(monsterdf['Job_Description']))
# test to make sure the array looks good
print(DegreeColumn1[0:20])
print(DegreeColumn2[0:20])
# Out:
# 1235
# 1235
# 74
# 74
# ["Bachelor's", 'BS', "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", 'BS', "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", "Bachelor's", 'BS', 'PhD']
# ["Bachelor's", 'No Mention', "Master's", 'No Mention', 'No Mention', 'No Mention', 'No Mention', 'No Mention', 'No Mention', 'BA', 'No Mention', 'BA', 'BA', "Bachelor's", "Bachelor's", 'BA', 'BA', 'No Mention', 'BA', 'No Mention']

# %%
# add the column to the google dataframe and the monster dataframe
googdf['Degree Requirement'] = DegreeColumn1
monsterdf['Degree Requirement'] = DegreeColumn2

# sepparate the dataset into analysts and non-analysts(the monster dataset is all analysts)
googdf_analyst = googdf[googdf['Category'] == 'IT & Data Management']
googdf_not_analyst = googdf[googdf['Category'] != 'IT & Data Management']
# Now we have three datasets:

# %%
# generate a count of the number of instances of each degree in each dataset 
monster_education_value_counts = monsterdf['Degree Requirement'].value_counts()
google_A_education_value_counts = googdf_analyst['Degree Requirement'].value_counts()
google_NA_education_value_counts = googdf_not_analyst['Degree Requirement'].value_counts()

# turn the each series into a DataFrame 
monster_education_value_counts_df = pd.DataFrame(monster_education_value_counts)
google_A_education_value_counts_df = pd.DataFrame(google_A_education_value_counts)
google_NA_education_value_counts_df = pd.DataFrame(google_NA_education_value_counts)

# reset the index of the DataFrames to include the degree names
monster_education_value_counts_df = monster_education_value_counts_df.reset_index()
google_A_education_value_counts_df = google_A_education_value_counts_df.reset_index()
google_NA_education_value_counts_df = google_NA_education_value_counts_df.reset_index()

# Change the data from a strict count to a percentage to make the data more comparable
monster_education_value_counts_df['Degree Requirement'] = monster_education_value_counts_df['Degree Requirement'].apply(lambda x: x*100/74)
google_A_education_value_counts_df['Degree Requirement'] = google_A_education_value_counts_df['Degree Requirement'].apply(lambda x: x*100/5)
google_NA_education_value_counts_df['Degree Requirement'] = google_NA_education_value_counts_df['Degree Requirement'].apply(lambda x: x*100/1230)

# %%
monster_education_value_counts_df
# Out:
#         index  Degree Requirement
# 0  No Mention           44.594595
# 1  Bachelor's           24.324324
# 2          BA           14.864865
# 3    Master's            9.459459
# 4         MBA            2.702703
# 5          BS            2.702703
# 6         PhD            1.351351

# %%
google_A_education_value_counts_df
# Out:
#   index  Degree Requirement
# 0   PhD                60.0
# 1    BS                40.0

# %%
google_NA_education_value_counts_df
# Out:
#         index  Degree Requirement
# 0  Bachelor's           77.642276
# 1  No Mention            8.130081
# 2         MBA            5.772358
# 3    Master's            4.146341
# 4          BS            3.333333
# 5         PhD            0.650407
# 6          BA            0.325203

# %%
# make a bar graph! 
fig = plt.figure(figsize=[10, 5])
plt.bar(x=google_A_education_value_counts_df['index'],
        height=google_A_education_value_counts_df['Degree Requirement'],
        color=['b', 'g', 'r', 'c', 'm', 'y', 'k'], 
        alpha=0.75)
plt.title("Degrees Required for Analysts at Google")
plt.ylabel("Percent of Sample Degrees")
# Out:
# Text(0,0.5,'Percent of Sample Degrees')

# %%
# another pie
fig = plt.figure(figsize=[10, 10])
plt.pie(x=google_A_education_value_counts_df['Degree Requirement'],
        labels=google_A_education_value_counts_df['index'],
        colors=['b', 'g', 'r', 'c', 'm', 'y', 'k'],
        autopct='%.1f%%', textprops={'fontsize': 14})
plt.title("Degrees Required for Analysts at Google")
# Out:
# Text(0.5,1,'Degrees Required for Analysts at Google')

# %%
# make a bar graph! 
fig = plt.figure(figsize=[10, 5])
plt.bar(x=google_NA_education_value_counts_df['index'],
        height=google_NA_education_value_counts_df['Degree Requirement'],
        color=['b', 'g', 'r', 'c', 'm', 'y', 'k'],
        alpha=0.75)
plt.title("Degrees Required for NON-Analysts at Google")
plt.ylabel("Percent of Sample Degrees")
# Out:
# Text(0,0.5,'Percent of Sample Degrees')

# %%
# and one more pie
fig = plt.figure(figsize=[10, 10])
plt.pie(x=google_NA_education_value_counts_df['Degree Requirement'],
        labels=google_NA_education_value_counts_df['index'],
        colors=['b', 'g', 'r', 'c', 'm', 'y', 'k'],
        autopct='%.1f%%', textprops={'fontsize': 14})
plt.title("Degrees Required for NON-Analysts at Google")
# Out:
# Text(0.5,1,'Degrees Required for NON-Analysts at Google')

# %%
# make a bar graph! 
fig = plt.figure(figsize=[10, 5])
plt.bar(x=monster_education_value_counts_df['index'],
        height=monster_education_value_counts_df['Degree Requirement'],
        color=['b', 'g', 'r', 'c', 'm', 'y', 'k'], 
        alpha=0.75)
plt.title("Degrees Required for US Analysts on Monster.com")
plt.ylabel("Percent of Sample Degrees")
# Out:
# Text(0,0.5,'Percent of Sample Degrees')

# %%
# and a pie
fig = plt.figure(figsize=[10, 10])
plt.pie(x=monster_education_value_counts_df['Degree Requirement'],
        labels=monster_education_value_counts_df['index'],
        colors=['b', 'g', 'r', 'c', 'm', 'y', 'k'],
        startangle=90, 
        autopct='%.1f%%', textprops={'fontsize': 14})
plt.title("Degrees Required for US Analysts on Monster.com")
# Out:
# Text(0.5,1,'Degrees Required for US Analysts on Monster.com')

# %%
#  
# 
#
#
#Conclusions:
# 1. If you want to work at google you NEED at least a Bachelor's Degree 
# 2. Most jobs at google that call for analyst skills are
#     focused on a specific area like finance or business.
#    In other words there is a very small number of jobs that are 
#     purely about analysis. 
# 3. Google's required education level is much higher 
#     than the rest of the country in geneally.
#

# %%
from List_of_Programming_Languages import LoPL
print(LoPL)
# Out:
# ['4th Dimension/4D', 'ABAP', 'ABC', 'ActionScript', 'Ada', 'Agilent VEE', 'Algol', 'Alice', 'Angelscript', 'Apex', 'APL', 'AppleScript', 'Arc', 'Arduino', 'ASP', 'AspectJ', 'Assembly', 'ATLAS', 'Augeas', 'AutoHotkey', 'AutoIt', 'AutoLISP', 'Automator', 'Avenue', 'Awk', 'Bash', 'Visual Basic', 'VBA', 'bc', 'BCPL', 'BETA', 'BlitzMax', 'Boo', 'Bourne Shell', 'Bro', 'C', 'C Shell', 'C#', 'C++', 'CLI', 'C-Omega', 'Caml', 'Ceylon', 'CFML', 'cg', 'Ch', 'CHILL', 'CIL', 'CL', 'OS', 'Clarion', 'Clean', 'Clipper', 'Clojure', 'CLU', 'COBOL', 'Cobra', 'CoffeeScript', 'ColdFusion', 'COMAL', 'Common Lisp', 'Coq', 'cT', 'Curl', 'D', 'Dart', 'DCL', 'DCPU-16', 'ASM', 'Delphi', 'Object Pascal', 'DiBOL', 'Dylan', 'E', 'eC', 'Ecl', 'ECMAScript', 'EGL', 'Eiffel', 'Elixir', 'Emacs Lisp', 'Erlang', 'Etoys', 'Euphoria', 'EXEC', 'F#', 'Factor', 'Falcon', 'Fancy', 'Fantom', 'Felix', 'Forth', 'Fortran', 'Fortress', 'Visual FoxPro', 'Gambas', 'GNU Octave', 'Go', 'Google AppsScript', 'Gosu', 'Groovy', 'Haskell', 'haXe', 'Heron', 'HPL', 'HyperTalk', 'Icon', 'IDL', 'Inform', 'Informix-4GL', 'INTERCAL', 'Io', 'Ioke', 'J', 'J#', 'JADE', 'Java', 'Java FX Script', 'JavaScript', 'JScript', 'JScript.NET', 'Julia', 'Korn Shell', 'Kotlin', 'LabVIEW', 'Ladder Logic', 'Lasso', 'Limbo', 'Lingo', 'Lisp', 'Logo', 'Logtalk', 'LotusScript', 'LPC', 'Lua', 'Lustre', 'M4', 'MAD', 'Magic', 'Magik', 'Malbolge', 'MANTIS', 'Maple', 'Mathematica', 'MATLAB', 'Max/MSP', 'MSP', 'MAXScript', 'MEL', 'Mercury', 'Mirah', 'Miva', 'ML', 'Monkey', 'Modula-2', 'Modula-3', 'MOO', 'Moto', 'MS-DOS Batch', 'MUMPS', 'NATURAL', 'Nemerle', 'Nimrod', 'NQC', 'NSIS', 'Nu', 'NXT-G', 'Oberon', 'Object Rexx', 'Objective-C', 'Objective-J', 'OCaml', 'Occam', 'ooc', 'Opa', 'OpenCL', 'OpenEdge ABL', 'OPL', 'Oz', 'Paradox', 'Parrot', 'Pascal', 'Perl', 'PHP', 'Pike', 'PILOT', 'PL/I', 'PL/SQL', 'SQL', 'Pliant', 'PostScript', 'POV-Ray', 'PowerBasic', 'PowerScript', 'PowerShell', 'Processing', 'Prolog', 'Puppet', 'Pure Data', 'Python', 'Q', 'R', 'Racket', 'REALBasic', 'REBOL', 'Revolution', 'REXX', 'RPG', 'Ruby', 'Rust', 'S', 'S-PLUS', 'SAS', 'Sather', 'Scala', 'Scheme', 'Scilab', 'Scratch', 'sed', 'Seed7', 'Self', 'Shell', 'SIGNAL', 'Simula', 'Simulink', 'Slate', 'Smalltalk', 'Smarty', 'SPARK', 'SPSS', 'SQR', 'Squeak', 'Squirrel', 'Standard ML', 'Suneido', 'SuperCollider', 'TACL', 'Tcl', 'Tex', 'thinBasic', 'TOM', 'Transact-SQL', 'Turing', 'TypeScript', 'Vala', 'Genie', 'VBScript', 'Verilog', 'VHDL', 'VimL', 'Visual Basic .NET', 'WebDNA', 'Whitespace', 'X10', 'xBase', 'XBase++', 'Xen', 'XPL', 'XSLT', 'XQuery', 'yacc', 'Yorick', 'Z shell']

# %% [markdown]
# # Conclusion - Ali
